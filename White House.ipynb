# %%
#Importing necessary libraries.
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading in all datasets.
df1 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2021_WAVES-ACCESS-RECORDS White House.csv")
df2 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.01_WAVES-ACCESS-RECORDS.csv")
df3 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.02_WAVES-ACCESS-RECORDS.csv")
df4 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.03_WAVES-ACCESS-RECORDS-.csv")
df5 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.04_WAVES-ACCESS-RECORDS.csv")
df6 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.05-WAVES-ACCESS-RECORDS.csv")
df7 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.06_WAVES-ACCESS-RECORDS.csv")
df8 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.07_WAVES-ACCESS-RECORDS.csv")
df9 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.08_WAVES-ACCESS-RECORDS.csv")
df10 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.09_WAVES-ACCESS-RECORDS.csv")
df11 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.10_WAVES-ACCESS-RECORDS.csv")
df12 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.11_WAVES-ACCESS-RECORDS.csv")
df13 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.12_WAVES-ACCESS-RECORDS.csv")
df14 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.01_WAVES-ACCESS-RECORDS.csv")
df15 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.02_WAVES-ACCESS-RECORDS.csv")
df16 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.03_WAVES-ACCESS-RECORDS.csv")
df17 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.04_WAVES-ACCESS-RECORDS.csv")
df18 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.05_WAVES-ACCESS-RECORDS.csv")
df19 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.06_WAVES-ACCESS-RECORDS.csv")
df20 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.07_WAVES-ACCESS-RECORDS.csv")
df21 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.08_WAVES-ACCESS-RECORDS.csv")
df22 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.09_WAVES-ACCESS-RECORDS.csv")
df23 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.10_WAVES-ACCESS-RECORDS.csv")
df24 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.11_WAVES-ACCESS-RECORDS.csv")
df25 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.12_WAVES-ACCESS-RECORDS.csv")
# Out:
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:11: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df10 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.09_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:12: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df11 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.10_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:14: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df13 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations/Datasets/White House/2022.12_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:15: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df14 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.01_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:16: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df15 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.02_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:17: DtypeWarning: Columns (7,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df16 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.03_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:18: DtypeWarning: Columns (7,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df17 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.04_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:19: DtypeWarning: Columns (7,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df18 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.05_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:20: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df19 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.06_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:21: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df20 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.07_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:22: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df21 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.08_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:23: DtypeWarning: Columns (7,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df22 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.09_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:24: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df23 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.10_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:25: DtypeWarning: Columns (7,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df24 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.11_WAVES-ACCESS-RECORDS.csv")
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\612180356.py:26: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df25 = pd.read_csv("C:/Users/kromi/OneDrive/Bellevue/Data Presentation and Visualizations\Datasets/White House/2023.12_WAVES-ACCESS-RECORDS.csv")

# %%
dfs = [df1, df2, df3, df4, df5, df6, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25]

#Making sure all datasets have the same column names.
for i, df in enumerate(dfs, start = 1):
    print(f"Columns in df{i}:")
    print(df.columns.tolist())
    print("-" * 40)
# Out:
# Columns in df1:
# ['NAMELAST', 'NAMEFIRST', 'NAMEMID', 'UIN', 'BDGNBR', 'ACCESS_TYPE', 'TOA', 'POA', 'TOD', 'POD', 'APPT_MADE_DATE', 'APPT_START_DATE', 'APPT_END_DATE', 'APPT_CANCEL_DATE', 'TOTAL_PEOPLE', 'LAST_UPDATEDBY', 'POST', 'LASTENTRYDATE', 'TERMINAL_SUFFIX', 'VISITEE_NAMELAST', 'VISITEE_NAMEFIRST', 'MEETING_LOC', 'MEETING_ROOM', 'CALLER_NAME_LAST', 'CALLER_NAME_FIRST', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df2:
# ['NAMELAST', 'NAMEFIRST', 'NAMEMID', 'UIN', 'BDGNBR', 'ACCESS_TYPE', 'TOA', 'POA', 'TOD', 'POD', 'APPT_MADE_DATE', 'APPT_START_DATE', 'APPT_END_DATE', 'APPT_CANCEL_DATE', 'TOTAL_PEOPLE', 'LAST_UPDATEDBY', 'POST', 'LASTENTRYDATE', 'TERMINAL_SUFFIX', 'VISITEE_NAMELAST', 'VISITEE_NAMEFIRST', 'MEETING_LOC', 'MEETING_ROOM', 'CALLER_NAME_LAST', 'CALLER_NAME_FIRST', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df3:
# ['NAMELAST', 'NAMEFIRST', 'NAMEMID', 'UIN', 'BDGNBR', 'ACCESS_TYPE', 'TOA', 'POA', 'TOD', 'POD', 'APPT_MADE_DATE', 'APPT_START_DATE', 'APPT_END_DATE', 'APPT_CANCEL_DATE', 'TOTAL_PEOPLE', 'LAST_UPDATEDBY', 'POST', 'LASTENTRYDATE', 'TERMINAL_SUFFIX', 'VISITEE_NAMELAST', 'VISITEE_NAMEFIRST', 'MEETING_LOC', 'MEETING_ROOM', 'CALLER_NAME_LAST', 'CALLER_NAME_FIRST', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df4:
# ['NAMELAST', 'NAMEFIRST', 'NAMEMID', 'UIN', 'BDGNBR', 'ACCESS_TYPE', 'TOA', 'POA', 'TOD', 'POD', 'APPT_MADE_DATE', 'APPT_START_DATE', 'APPT_END_DATE', 'APPT_CANCEL_DATE', 'TOTAL_PEOPLE', 'LAST_UPDATEDBY', 'POST', 'LASTENTRYDATE', 'TERMINAL_SUFFIX', 'VISITEE_NAMELAST', 'VISITEE_NAMEFIRST', 'MEETING_LOC', 'MEETING_ROOM', 'CALLER_NAME_LAST', 'CALLER_NAME_FIRST', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df5:
# ['NAMELAST', 'NAMEFIRST', 'NAMEMID', 'UIN', 'BDGNBR', 'ACCESS_TYPE', 'TOA', 'POA', 'TOD', 'POD', 'APPT_MADE_DATE', 'APPT_START_DATE', 'APPT_END_DATE', 'APPT_CANCEL_DATE', 'TOTAL_PEOPLE', 'LAST_UPDATEDBY', 'POST', 'LASTENTRYDATE', 'TERMINAL_SUFFIX', 'VISITEE_NAMELAST', 'VISITEE_NAMEFIRST', 'MEETING_LOC', 'MEETING_ROOM', 'CALLER_NAME_LAST', 'CALLER_NAME_FIRST', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df6:
# ['NAMELAST', 'NAMEFIRST', 'NAMEMID', 'UIN', 'BDGNBR', 'ACCESS_TYPE', 'TOA', 'POA', 'TOD', 'POD', 'APPT_MADE_DATE', 'APPT_START_DATE', 'APPT_END_DATE', 'APPT_CANCEL_DATE', 'TOTAL_PEOPLE', 'LAST_UPDATEDBY', 'POST', 'LASTENTRYDATE', 'TERMINAL_SUFFIX', 'VISITEE_NAMELAST', 'VISITEE_NAMEFIRST', 'MEETING_LOC', 'MEETING_ROOM', 'CALLER_NAME_LAST', 'CALLER_NAME_FIRST', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df7:
# ['NAMELAST', 'NAMEFIRST', 'NAMEMID', 'UIN', 'BDGNBR', 'ACCESS_TYPE', 'TOA', 'POA', 'TOD', 'POD', 'APPT_MADE_DATE', 'APPT_START_DATE', 'APPT_END_DATE', 'APPT_CANCEL_DATE', 'TOTAL_PEOPLE', 'LAST_UPDATEDBY', 'POST', 'LASTENTRYDATE', 'TERMINAL_SUFFIX', 'VISITEE_NAMELAST', 'VISITEE_NAMEFIRST', 'MEETING_LOC', 'MEETING_ROOM', 'CALLER_NAME_LAST', 'CALLER_NAME_FIRST', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df8:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df9:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df10:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df11:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df12:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df13:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df14:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df15:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df16:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# ----------------------------------------
# Columns in df17:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'Caller Room', 'Release Date']
# ----------------------------------------
# Columns in df18:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'Caller Room', 'Release Date']
# ----------------------------------------
# Columns in df19:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'Caller Room', 'Release Date']
# ----------------------------------------
# Columns in df20:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'Caller Room', 'Release Date']
# ----------------------------------------
# Columns in df21:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'Caller Room', 'Release Date']
# ----------------------------------------
# Columns in df22:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'Caller Room', 'Release Date']
# ----------------------------------------
# Columns in df23:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'Caller Room', 'Release Date']
# ----------------------------------------
# Columns in df24:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'Caller Room', 'Release Date']
# ----------------------------------------
# Columns in df25:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'Caller Room', 'Release Date']
# ----------------------------------------
# Columns in df26:
# ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'Caller Room', 'Release Date']
# ----------------------------------------

# %%
#Changing column names across DataFrames to ensure consistency before merging.
reference_columns = dfs[7].columns
for i in range(7):
    dfs[i].columns = reference_columns

print("Updated column names for df1 to df7:")
for i in range(7):
    print(f"df{i+1} columns: {dfs[i].columns.tolist()}")
# Out:
# Updated column names for df1 to df7:
# df1 columns: ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# df2 columns: ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# df3 columns: ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# df4 columns: ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# df5 columns: ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# df6 columns: ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']
# df7 columns: ['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR', 'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date', 'Appointment Start Date', 'Appointment End Date', 'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST', 'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name', 'Visitee First Name', 'Meeting Location', 'Meeting Room', 'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE']

# %%
#Merging all datasets into one.
df = pd.concat(dfs, ignore_index = True)

# %%
#Combining 'Last Name' and 'First Name' into a 'Visitor' column
if 'Last Name' in df.columns and 'First Name' in df.columns:
    df['Visitor'] = df['Last Name'] + ", " + df['First Name'] + " " + df['Middle Initial']
else:
    print("The 'Last Name' or 'First Name' column is missing.")

print(df[['Last Name', 'First Name', 'Visitor']].head())
# Out:
#   Last Name First Name             Visitor
# 0    AAKHUU   BOLORMAA  AAKHUU, BOLORMAA N
# 1    AASSAR        MIA       AASSAR, MIA L
# 2    ABALOS     JANILA    ABALOS, JANILA L
# 3   ABARCAR       KARA     ABARCAR, KARA N
# 4    ABBOTT    NICOLAS   ABBOTT, NICOLAS P

# %%
#Combining 'Visitee Last Name' and 'Visitee First Name' into a 'Visitee' column
if 'Visitee Last Name' in df.columns and 'Visitee First Name' in df.columns:
    df['Visitee'] = df['Visitee Last Name'] + ", " + df['Visitee First Name']
else:
    print("The 'Last Name' or 'First Name' column is missing.")

print(df[['Visitee Last Name', 'Visitee First Name', 'Visitee']].head())
# Out:
#   Visitee Last Name Visitee First Name           Visitee
# 0            Office           Visitors  Office, Visitors
# 1            Office           Visitors  Office, Visitors
# 2              COLE              KATIE       COLE, KATIE
# 3            Office           Visitors  Office, Visitors
# 4            Mellul                Ian       Mellul, Ian

# %%
#Combining 'Caller Last Name' and 'Caller First Name' into a 'Caller' column
if 'Caller Last Name' in df.columns and 'Caller First Name' in df.columns:
    df['Caller'] = df['Caller Last Name'] + ", " + df['Caller First Name']
else:
    print("The 'Last Name' or 'First Name' column is missing.")

print(df[['Caller Last Name', 'Caller First Name', 'Caller']].head())
# Out:
#   Caller Last Name Caller First Name               Caller
# 0         SCHWARTZ            PEYTON     SCHWARTZ, PEYTON
# 1         SCHWARTZ            PEYTON     SCHWARTZ, PEYTON
# 2             COLE             KATIE          COLE, KATIE
# 3             COLE             KATIE          COLE, KATIE
# 4      GIAMMARELLA            ALYSSA  GIAMMARELLA, ALYSSA

# %%
#Finding most visited people.
df['Caller'].value_counts().head(10)
# Out:
# Caller
# WAVES, VISITORSOFFICE    658727
# WW, TOUR                  64881
# LEE, JANICE               50382
# SCHWARTZ, PEYTON          36646
# MILLS, GIONELLY           31819
# JONES, HALEY              26272
# TELEKY, EDWARD            21647
# ALLEY, BOWLING            12739
# TROCOLA, AMANDA           11028
# HECMANCZUK, LYDIA          9102
# Name: count, dtype: int64

# %%
df['Caller'] = df['Caller'].replace({
    'WAVES, VISITORSOFFICE': "Visitor's Office",
    'WW, TOUR': 'Tours'})

# %%
#Plotting bar chart of top two visitees.
visitor_counts = df['Caller'].value_counts()

top_2_visitors = visitor_counts.nlargest(2)

#plt.figure(figsize=(12, 6))
top_2_visitors.plot(kind='bar', color='#2d4578', edgecolor='black')

plt.xlabel("Visitee")
plt.ylabel("Number of Visits")
plt.title("Top 2 Visitees for White House Visits")
plt.xticks(rotation = 0)
plt.grid(axis='y')
plt.tight_layout()

plt.show()

# %%
#Keeping only rows where the first name is 'Tour' to explore White House tour trends.
df = df[df['Caller First Name'] == 'TOUR']

# %%
#Finging top 10 visted people from tours.
df['Visitee'].value_counts().head(10)
# Out:
# Visitee
# Black, Jonathan     351
# McCool, Daniela     231
# Zhong, XiaoQiang    213
# Slack, William      206
# McKay, Roland       204
# Carr, Lisa          200
# Scott, Brian        192
# Reddy, Vinay        190
# Hart, Elizabeth     181
# Presman, Dylan      180
# Name: count, dtype: int64

# %%
#Finging top 10 visted people from tours.
df['Visitee'].value_counts().sum()
# Out:
# 39302

# %%
df.isna().sum()
# Out:
# Last Name                      1
# First Name                     0
# Middle Initial                 0
# UIN                            0
# BDGNBR                     48886
# Access Type                    0
# TOA                         8395
# POA                        64881
# TOD                        64881
# POD                        54852
# Appointment Made Date          0
# Appointment Start Date         0
# Appointment End Date           0
# Appointment Cancel Date    64881
# Total People                   0
# Last Updated By                0
# POST                           0
# Last Entry Date                0
# Terminal Suffix                0
# Visitee Last Name              0
# Visitee First Name             0
# Meeting Location               0
# Meeting Room                   0
# Caller Last Name               0
# Caller First Name              0
# CALLER_ROOM                64881
# RELEASEDATE                36831
# Caller Room                64881
# Release Date               28050
# Visitor                        1
# Visitee                        0
# Caller                         0
# dtype: int64

# %%
#Dropping unecessary columns
columns_to_drop = [
    'UIN',
    'BDGNBR',
    'Access Type',
    'POA', 
    'TOD', 
    'POD', 
    'Appointment Cancel Date',
    'POST',
    'CALLER_ROOM', 
    'RELEASEDATE', 
    'Caller Room', 
    'Release Date'
]

df = df.drop(columns=columns_to_drop, errors='ignore')

# %%
#Keeping only a school year's worth of data.
df['Appointment Start Date'] = pd.to_datetime(df['Appointment Start Date'])

start_date = '2022-08-01'
end_date = '2023-06-30'

df = df[(df['Appointment Start Date'] >= start_date) & (df['Appointment Start Date'] <= end_date)]

# %%
df
# Out:
#               Last Name   First Name Middle Initial                  TOA  \
# 161739           ABALOS      JEFFREY              A  Aug 22 2022  8:38PM
# 161741          ABAYOMI    AKINTUNDE              N  Aug 17 2022  8:21PM
# 161748         ABDALLAH      CHARBEL              N                  NaN
# 161749         ABDALLAH        JOYCE              N  Aug 28 2022  3:02PM
# 161753       ABDELSAYED       CELINE              J  Aug 14 2022  1:43PM
# ...                 ...          ...            ...                  ...
# 781889            ZINAH       MAHLET              M  Jun 28 2023  9:38PM
# 781939  ZOLLINGERABEYTA  CHRISTOPHER              J  Jun  9 2023  8:50PM
# 781998          ZULUAGA    VALENTINA              N  Jun 26 2023  7:59PM
# 782015           ZUNIGA      GUSTAVO              A                  NaN
# 782026           ZURINE         EMMA              A  Jun 11 2023  1:01PM
#
#        Appointment Made Date Appointment Start Date Appointment End Date  \
# 161739       8/20/2022 21:00    2022-08-22 20:45:00      8/22/2022 23:59
# 161741       8/15/2022 20:00    2022-08-17 20:00:00      8/17/2022 23:59
# 161748       8/26/2022 15:00    2022-08-28 15:00:00      8/28/2022 23:59
# 161749       8/26/2022 15:00    2022-08-28 15:00:00      8/28/2022 23:59
# 161753       8/12/2022 13:30    2022-08-14 13:15:00      8/14/2022 23:59
# ...                      ...                    ...                  ...
# 781889       6/26/2023 22:00    2023-06-28 21:45:00      6/28/2023 23:59
# 781939        6/8/2023 18:00    2023-06-09 21:30:00       6/9/2023 23:59
# 781998       6/24/2023 20:00    2023-06-26 20:00:00      6/26/2023 23:59
# 782015        6/8/2023 15:30    2023-06-10 15:30:00      6/10/2023 23:59
# 782026        6/9/2023 13:30    2023-06-11 13:30:00      6/11/2023 23:59
#
#         Total People Last Updated By  Last Entry Date Terminal Suffix  \
# 161739           6.0              TW  8/21/2022 11:45              TW
# 161741           7.0              TW  8/17/2022 18:01              TW
# 161748           3.0              TW  8/26/2022 15:49              TW
# 161749           3.0              TW  8/26/2022 15:49              TW
# 161753           6.0              TW  8/14/2022 13:25              TW
# ...              ...             ...              ...             ...
# 781889           4.0              TW   6/27/2023 5:37              TW
# 781939           2.0              TW   6/8/2023 18:14              TW
# 781998           6.0              TW  6/25/2023 11:12              TW
# 782015           6.0              TW   6/8/2023 15:36              TW
# 782026           3.0              TW   6/9/2023 13:34              TW
#
#        Visitee Last Name Visitee First Name Meeting Location Meeting Room  \
# 161739          Bradbury          Katherine               WH    WEST WING
# 161741             Brown             Quincy               WH    WEST WING
# 161748              Pica              Karen               WH    WEST WING
# 161749              Pica              Karen               WH    WEST WING
# 161753              Plat               Jana               WH    WEST WING
# ...                  ...                ...              ...          ...
# 781889              Lacy             Dwight               WH    WEST WING
# 781939            Beatty            Roxanne               WH    WEST WING
# 781998     Manners-Weber              David               WH    WEST WING
# 782015            Barton             Joseph               WH    WEST WING
# 782026         Fernandes           Benjamin               WH    WEST WING
#
#        Caller Last Name Caller First Name                         Visitor  \
# 161739               WW              TOUR               ABALOS, JEFFREY A
# 161741               WW              TOUR            ABAYOMI, AKINTUNDE N
# 161748               WW              TOUR             ABDALLAH, CHARBEL N
# 161749               WW              TOUR               ABDALLAH, JOYCE N
# 161753               WW              TOUR            ABDELSAYED, CELINE J
# ...                 ...               ...                             ...
# 781889               WW              TOUR                 ZINAH, MAHLET M
# 781939               WW              TOUR  ZOLLINGERABEYTA, CHRISTOPHER J
# 781998               WW              TOUR            ZULUAGA, VALENTINA N
# 782015               WW              TOUR               ZUNIGA, GUSTAVO A
# 782026               WW              TOUR                  ZURINE, EMMA A
#
#                      Visitee Caller
# 161739   Bradbury, Katherine  Tours
# 161741         Brown, Quincy  Tours
# 161748           Pica, Karen  Tours
# 161749           Pica, Karen  Tours
# 161753            Plat, Jana  Tours
# ...                      ...    ...
# 781889          Lacy, Dwight  Tours
# 781939       Beatty, Roxanne  Tours
# 781998  Manners-Weber, David  Tours
# 782015        Barton, Joseph  Tours
# 782026   Fernandes, Benjamin  Tours
#
# [39302 rows x 20 columns]

# %%
#Extracting month data.
df['Appointment Start Date'] = pd.to_datetime(df['Appointment Start Date'])
df['YearMonth'] = df['Appointment Start Date'].dt.to_period('M')

# %%
#Grouping by 'YearMonth' and summing 'Total People'.
monthly_visits = df.groupby('YearMonth')['Total People'].sum().reset_index()

# %%
#Converting 'YearMonth' back to datetime for plotting.
monthly_visits['YearMonth'] = monthly_visits['YearMonth'].dt.to_timestamp()

#Plotting a line graph.
plt.figure(figsize=(12, 6))
plt.plot(monthly_visits['YearMonth'], monthly_visits['Total People'], marker='o', linestyle='-', color='#ff5757')

plt.ylim(bottom=0)
plt.xlabel("Month")
plt.ylabel("Number of Attendees")
plt.title("Tour Attendees by Month")
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

plt.show()

# %%
df['Total People'].sum()
# Out:
# 187860.0

# %%
#Extracting the day of the week (0=Monday, 6=Sunday)
df['Day of Week'] = df['Appointment Start Date'].dt.day_name()

day_counts = df['Day of Week'].value_counts().reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# %%
#Plotting a bar chart.
day_counts.plot(kind='bar', edgecolor='black', color='#2d4578')

plt.xlabel("Day of the Week")
plt.ylabel("Number of Visits")
plt.title("Visits by Day of the Week")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()

plt.show()

# %%
#Extract time data.
df['Hour'] = df['Appointment Start Date'].dt.hour
hourly_counts = df['Hour'].value_counts().sort_index()

# %%
#Plotting a step chart.
hourly_counts = df['Hour'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
plt.step(hourly_counts.index, hourly_counts.values, where='mid', marker='o', linestyle='-')

plt.xlabel("Hour of the Day")
plt.ylabel("Number of Appointments")
plt.title("Distribution of Appointments by Hour")
plt.grid(axis='y')
plt.tight_layout()

plt.show()

# %%
#Adding hour category to simplify coloring of graph.
df['Hour Category'] = pd.cut(
    df['Hour'],
    bins = [11, 16, 22],
    labels = ['School Hours', 'After School Hours'],
    right = False)

#Plotting a stacked bar chart.
hourly_day_counts = df.groupby(['Day of Week', 'Hour Category']).size().unstack(fill_value=0)

ordered_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
hourly_day_counts = hourly_day_counts.reindex(ordered_days)

colors = ['#2d4578', '#ff5757']

plt.figure(figsize=(12, 8))
hourly_day_counts.plot(kind='bar', stacked=True, color=colors, edgecolor='black')

plt.xlabel("Day of the Week")
plt.ylabel("Number of Tours")
plt.title("Tour Times Across Days of the Week")
plt.xticks(rotation=45)
plt.legend(title='Hour of Day', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y')
plt.tight_layout()

plt.show()
# Out:
# C:\Users\kromi\AppData\Local\Temp\ipykernel_9672\3292891020.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hourly_day_counts = df.groupby(['Day of Week', 'Hour Category']).size().unstack(fill_value=0)
